# %%
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
df=pd.read_csv("weather_data.csv")
del df["Unnamed: 0"]
df
# Out:
#                  City    Lat     Lon  Max Temp  Humidity  Cloudiness  \
# 0        punta arenas -53.15  -70.92     33.80        59          61
# 1           hithadhoo  -0.60   73.08     82.87        78         100
# 2           kungurtug  50.60   97.52     69.33        38          99
# 3    fort myers beach  26.45  -81.95     81.00        74           1
# 4         tuktoyaktuk  69.45 -133.04     59.00        77          90
# ..                ...    ...     ...       ...       ...         ...
# 575            mikuni  36.22  136.15     84.20        70          90
# 576   fort-shevchenko  44.51   50.26     79.61        37           0
# 577        porto novo   6.50    2.60     75.20        94          20
# 578        nkhotakota -12.93   34.30     65.64        76          86
# 579         longjiang  47.33  123.18     76.24        69         100
#
#      Wind Speed Country        Date
# 0          8.05      CL  1595904358
# 1         14.05      MV  1595904370
# ...

# %%
html =df.to_html(classes="table thead-light table-striped table-hover table-light table-responsive-sm")

# %%
soup = bs(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <table border="1" class="dataframe table thead-light table-striped table-hover table-light table-responsive-sm">
#  <thead>
#   <tr style="text-align: right;">
#    <th>
#    </th>
#    <th>
#     City
#    </th>
#    <th>
#     Lat
#    </th>
#    <th>
#     Lon
#    </th>
#    <th>
#     Max Temp
#    </th>
#    <th>
#     Humidity
#    </th>
#    <th>
#     Cloudiness
#    </th>
#    <th>
#     Wind Speed
#    </th>
#    <th>
#     Country
#    </th>
#    <th>
#     Date
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr>
#    <th>
#     0
#    </th>
#    <td>
#     punta arenas
#    </td>
#    <td>
#     -53.15
#    </td>
#    <td>
#     -70.92
#    </td>
#    <td>
#     33.80
#    </td>
#    <td>
#     59
#    </td>
#    <td>
#     61
#    </td>
#    <td>
#     8.05
#    </td>
#    <td>
#     CL
#    </td>
#    <td>
#     1595904358
#    </td>
#   </tr>
#   <tr>
#    <th>
#     1
#    </th>
#    <td>
#     hithadhoo
#    </td>
#    <td>
#     -0.60
#    </td>
#    <td>
# ...
